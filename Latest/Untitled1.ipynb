# %%
import heapq

# %%
new_array = [23,55,2,4235,543,235,2,3,5235]

# %%
new_heap = heapq.heapify(new_array)

# %%
heapq.heappush(new_array, 20000)

# %%
new_array
# Out:
# [2, 3, 2, 55, 543, 235, 23, 4235, 5235, 20000]

# %%
heapq.heappop(new_array)
# Out:
# 2

# %%
new_array
# Out:
# [2, 3, 23, 55, 543, 235, 20000, 4235, 5235]

# %%
from collections import deque

# %%
new_que = deque([2,3,43,5,35,53,53,53,5353,3,23])

# %%
new_que.append("something")

# %%
new_que.popleft()
# Out:
# 2
