# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - The idea here is to look at the returns of the stock on a daily basis and combine it with the idea of maximal contiguous subarray sum.
# - We sum the returns from left to right and we keep a variable to keep track of the maximum profit so far.
# - We keep on adding the new profit to the current profit sequence and we update the maximum proft whenever the current profit suquence sum go above the maximum value.
# - Once we get current_profit <0, we define the current_profit=0 to make sure that we buy only afterwards (whenever we have a negative profit, it means that we can buy the stock later to get a deeper valley).

# %%
a = [1,2,3,4,5]

# %%
a[2:4] = [1,2]

# %%
a
# Out:
# [1, 2, 1, 2, 5]
