# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def Pal_ind_identifier(S,i,j):
  if i==j:
    return True
  if Pal_ind_identifiers(S,i+1,j-1) and S[i] == S[j]:
    return True
