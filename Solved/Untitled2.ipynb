# %% [markdown]
# ![Screenshot%20from%202020-05-24%2014-01-40.png](attachment:Screenshot%20from%202020-05-24%2014-01-40.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
import math
def hallSale(p,d,m,s):
    if s<p:
        return 0
    if d==0:
        return s//p
    #making d negetive so its actually discount
    d*=-1
    last_disc_game =  math.floor((m-p)/d +1)
    print("last_disc_game: ",last_disc_game)
    # remainng money once min disocunt is reached
    rem_money = s - (last_disc_game*(2*p + d*(last_disc_game-1)))//2
    print("remianing_money:",rem_money)
    if rem_money>0:
        if not m==0:
            rem_games_bought = rem_money//m
        print("rem_games_bough: ",rem_games_bought)
        return last_disc_game+rem_games_bought
    else:
        num_items=0
        rem_money=s
        for i in range(0,last_disc_game):
            rem_money -= p + i*d
            if rem_money<0:
                return i
            
#Following is the naive way of doing it
#     num_games = 0
#     i=0
#     while(True):
#         new_discount_price = p+i*(-d)
#         if new_discount_price>=m:
#             s-= new_discount_price
#         else:
#             s-=m
#         if s<0:
#             return i
#         else:
#             i+=1




# if __name__=="__main__":
#     p,d,m,s = list(map(int,input().strip().split()))
#     print(hallSale(p,d,m,s))

# %%
# hallSale(100,19,1,180)
hallSale(46,41,4,1546)
# Out:
# 375

# %%
1495//4
# Out:
# 373
