# %% [markdown]
# ![Screenshot%20from%202020-06-05%2017-01-20.png](attachment:Screenshot%20from%202020-06-05%2017-01-20.png)

# %%
# cook your dish here
#int(input().strip())
#list(map(int,input().strip().split()))

if __name__=="__main__":
#     T = int(input().strip())
    T=2
    for _ in range(T):
#         N =int(input().strip())
        N = T+1
        current_row = [i for i in range(1,N+1)]
        matrix_string= ' '.join(list(map(str,current_row)))
        for i in range(1,N):
            current_row=[el+N for el in current_row]
            current_row.reverse()
            matrix_string+='\n'+' '.join(list(map(str,current_row)))
        print(matrix_string)
# Out:
# 1 2 3
# 6 5 4
# 7 8 9
# 1 2 3
# 6 5 4
# 7 8 9
