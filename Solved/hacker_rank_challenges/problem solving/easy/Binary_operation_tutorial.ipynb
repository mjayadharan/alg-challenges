# %% [markdown]
# ## Convertions
# * int to binary: `bin(integer)`
# * bin to int: `int(binary_num,2)`

# %% [markdown]
# ![Screenshot%20from%202020-06-24%2013-51-21.png](attachment:Screenshot%20from%202020-06-24%2013-51-21.png)
