# %% [markdown]
# ![Screenshot%20from%202020-05-30%2015-39-12.png](attachment:Screenshot%20from%202020-05-30%2015-39-12.png)

# %% [markdown]
# - Useful test case
# ![Screenshot%20from%202020-05-30%2015-39-42.png](attachment:Screenshot%20from%202020-05-30%2015-39-42.png)

# %%
def absolutePermutation(n, k):
    if k==0:
        return [i for i in range(1,n+1)]
    elif n%(2*k)!=0:
        return [-1]
    else:
        lowest_order=[]
        for i in range(1,n+1,(2*k)):
            lowest_order+=[j for j in range(i+k,i+2*k)]
            lowest_order+=[j for j in range(i,i+k)]
        return lowest_order


# if __name__ == '__main__':
#     fptr = open(os.environ['OUTPUT_PATH'], 'w')

#     t = int(input())

#     for t_itr in range(t):
#         nk = input().split()

#         n = int(nk[0])

#         k = int(nk[1])

#         result = absolutePermutation(n, k)

#         fptr.write(' '.join(map(str, result)))
#         fptr.write('\n')

#     fptr.close()
