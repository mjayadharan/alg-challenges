# %% [markdown]
# ![Screenshot%20from%202020-05-23%2023-14-26.png](attachment:Screenshot%20from%202020-05-23%2023-14-26.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
def beautifulTriplets(d,arr):
    n= len(arr)
    num_beaut_triplets=0
    for i in range(n-2):
        for j in range(i+1,n):
            if arr[j]-arr[i]==d and j<n-1:
                for k in range(j+1,n):
                    if arr[k]-arr[j]==d:
                        num_beaut_triplets+=1
    return num_beaut_triplets




# if __name__=="__main__":
#     n,d = list(map(int,input().strip().split()))
#     arr = list(map(int,input().strip().split()))
#     print(beautifulTriplets(d,arr))
