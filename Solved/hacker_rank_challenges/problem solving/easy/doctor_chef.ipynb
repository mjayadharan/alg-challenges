# %% [markdown]
# ![Screenshot%20from%202020-07-04%2016-36-46.png](attachment:Screenshot%20from%202020-07-04%2016-36-46.png)

# %%
if __name__=="__main__":
    T = int(input())
    for _ in range(T):
        N,x = list(map(int,input().strip().split()))
        infect_list = list(map(int,input().strip().split()))
        infect_list_updated = [[el,el] for el in infect_list]
        infect_list_updated.sort(key=lambda el: el[0])
        num_days = 0
        while (infect_list_updated[-1][0]):
            num_people_cured = min(x,infect_list_updated[-1][0])
            infect_list_updated[-1][0] -= num_people_cured
            x = 2*num_people_cured
            print(x)
#             print([el[0] for el in infect_list_updated])
#             print(infect_list_updated)
            for i in range(N):
                infect_list_updated[i][0] = min(2*infect_list_updated[i][0], infect_list_updated[i][1])
            num_days += 1
            infect_list_updated.sort(key=lambda el: el[0])
#             print([el[0] for el in infect_list_updated])
        print(num_days)
# Out:
# 1
# 3 10
# 20 1 110
# 20
# 40
# 80
# 160
# 120
# 40
# 2
# 7
