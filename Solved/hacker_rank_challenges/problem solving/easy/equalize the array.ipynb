# %% [markdown]
# ![Screenshot%20from%202020-05-23%2017-39-59.png](attachment:Screenshot%20from%202020-05-23%2017-39-59.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
def equalizeArray(arr):
    # unique_list = list(set(arr))
    # unique_list.sort()
    # el_count = [0]*len(unique_list)
    # for el in arr:

    dic = {}
    for el in arr:
        str_el = str(el)
        if str_el in dic:
            dic[str_el]+=1
        else:
            dic[str_el]=1
    repetition_count = list(dic.values())
    return len(arr)-max(repetition_count)
        


# if __name__=="__main__":
#     n = int(input().strip())
#     arr = list(map(int,input().strip().split()))
#     print(equalizeArray(arr))
