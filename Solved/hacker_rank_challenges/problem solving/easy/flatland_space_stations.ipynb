# %% [markdown]
# ![Screenshot%20from%202020-05-29%2016-58-45.png](attachment:Screenshot%20from%202020-05-29%2016-58-45.png)

# %%
# Complete the flatlandSpaceStations function below.
import math
def flatlandSpaceStations(n, c):
    max_distance=0
    if n==len(c):
        return max_distance
    s = ["0" for i in range(n)]
    for el in c:
        s[el]="1"
    s_str = "".join(s)
    s_no_space_station = s_str.split("1")
    print(s_no_space_station)
    max_no_space_staion_length = max(s_no_space_station,key= lambda k: len(k))
    print(max_no_space_staion_length,len(max_no_space_staion_length))
    print(s_no_space_station[-1])
    return max([math.ceil(len(max_no_space_staion_length)/2),len(s_no_space_station[0]),len(s_no_space_station[-1]) ])
#     if s_no_space_station[0]==max_no_space_staion_length or s_no_space_station[-1]==max_no_space_staion_length:
#         return len(max_no_space_staion_length)
#     else:
#         return len(max_no_space_staion_length)//2 if len(max_no_space_staion_length)%2==0 else len(max_no_space_staion_length)//2 + 1

# %%
c=[4 ,76, 16, 71, 56, 7 ,77 ,31 ,2 ,66, 12, 32, 57, 11, 19, 14, 42]
flatlandSpaceStations(90,c)
# Out:
# ['00', '0', '00', '000', '', '0', '0', '00', '00000000000', '', '000000000', '0000000000000', '', '00000000', '0000', '0000', '', '000000000000']
# 0000000000000 13
# 000000000000
# 12

# %%
c=[0,4]
flatlandSpaceStations(5,c)
# Out:
# ['', '000', '']
# 000 3
# 2
