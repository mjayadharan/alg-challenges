# %% [markdown]
# ![Screenshot%20from%202020-05-31%2016-24-13.png](attachment:Screenshot%20from%202020-05-31%2016-24-13.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

def dfs(i,j,matrix):
    if i>=n or j>=m or matrix[i][j]==2 or matrix[i][j]==0 or i<0 or j<0:
        return 0
    else:
        matrix[i][j]=2
        return 1+(dfs(i+1,j,matrix)+dfs(i-1,j,matrix)+dfs(i,j+1,matrix)+dfs(i,j-1,matrix)+dfs(i+1,j-1,matrix)+dfs(i+1,j+1,matrix)+dfs(i-1,j-1,matrix)+dfs(i-1,j+1,matrix))
# Complete the connectedCell function below.
def connectedCell(matrix):
    biggest_nbd = 0
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            biggest_nbd = max(biggest_nbd,dfs(i,j,matrix))
    return biggest_nbd
# if __name__ == '__main__':
#     fptr = open(os.environ['OUTPUT_PATH'], 'w')

#     n = int(input())

#     m = int(input())

#     matrix = []

#     for _ in range(n):
#         matrix.append(list(map(int, input().rstrip().split())))

#     result = connectedCell(matrix)

#     fptr.write(str(result) + '\n')

#     fptr.close()
