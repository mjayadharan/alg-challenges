# %% [markdown]
# ![Screenshot%20from%202020-05-31%2015-17-04.png](attachment:Screenshot%20from%202020-05-31%2015-17-04.png)

# %%
import math
import os
import random
import re
import sys

# Complete the pairs function below.
def pairs(k, arr):
    num_pairs=0
    arr_set = set(arr)
    # arr.sort()
    # n = len(arr)
    # for i in range(n):
    #     for j in range(i+1,n):
    #         diff = arr[j]-arr[i]
    #         if diff==k:
    #             # print(arr[i],arr[j])
    #             num_pairs+= 1 
    #             break
    #         elif diff>k:
    #             break
    arr_added_k = {el+k for el in arr}
    num_pairs = len(arr_set & arr_added_k)
    return num_pairs

# if __name__ == '__main__':
#     fptr = open(os.environ['OUTPUT_PATH'], 'w')

#     nk = input().split()

#     n = int(nk[0])

#     k = int(nk[1])

#     arr = list(map(int, input().rstrip().split()))

#     result = pairs(k, arr)

#     fptr.write(str(result) + '\n')

#     fptr.close()
