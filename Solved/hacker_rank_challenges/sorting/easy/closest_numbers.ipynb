# %% [markdown]
# ![Screenshot%20from%202020-05-26%2016-35-22.png](attachment:Screenshot%20from%202020-05-26%2016-35-22.png)

# %%
# Complete the closestNumbers function below.
def closestNumbers(arr):
    result_array=[]
    least_diff= abs(arr[1]-arr[0])
    arr.sort()
    for i in range(len(arr)-1):
        if abs(arr[i+1]-arr[i])==least_diff:
            result_array+=[arr[i],arr[i+1]]
        elif abs(arr[i+1]-arr[i])<least_diff:
            least_diff = abs(arr[i+1]-arr[i])
            result_array=[arr[i],arr[i+1]]
    return result_array

# if __name__ == '__main__':
#     fptr = open(os.environ['OUTPUT_PATH'], 'w')

#     n = int(input())

#     arr = list(map(int, input().rstrip().split()))

#     result = closestNumbers(arr)

#     fptr.write(' '.join(map(str, result)))
#     fptr.write('\n')

#     fptr.close()
