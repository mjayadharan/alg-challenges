# %% [markdown]
# ![Screenshot%20from%202020-05-26%2014-07-10.png](attachment:Screenshot%20from%202020-05-26%2014-07-10.png)

# %%
import math
import os
import random
import re
import sys

def insertionSort1(n, arr):
    end_el = arr[n-1]
    if n==1:
        print(end_el)
    else:
        for i in range(n-2,-1,-1):
            if arr[i]>=end_el:
                arr[i+1]=arr[i]
            elif arr[i]<end_el:
                arr[i+1]=end_el
                for el in arr:
                    print(el,end=' ')
                print()
                break
            if i==0:
                arr[i+1]=arr[i]
                arr[i]=end_el
                for el in arr:
                    print(el, end=' ')
                print()



# Complete the insertionSort2 function below.
def insertionSort2(n, arr):
    if n==1:
        print(arr[0])
    else:
        for end_index in range(1,n):
            insertionSort1(end_index+1,arr)

    


# if __name__ == '__main__':
#     n = int(input())

#     arr = list(map(int, input().rstrip().split()))

#     insertionSort2(n, arr)
