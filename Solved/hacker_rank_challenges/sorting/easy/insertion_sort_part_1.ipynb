# %% [markdown]
# ![Screenshot%20from%202020-05-26%2013-52-33.png](attachment:Screenshot%20from%202020-05-26%2013-52-33.png)

# %%
# Complete the insertionSort1 function below.
def insertionSort1(n, arr):
    end_el = arr[-1]
    if n==1:
        print(end_el)
    else:
        for i in range(n-2,-1,-1):
            if arr[i]>=end_el:
                arr[i+1]=arr[i]
                for el in arr:
                    print(el, end=' ')
                print()
            # elif arr[i]>=end_el:
            #     arr[i+1]=arr[i]
            #     arr[i]=end_el
            #     for el in arr:
            #         print(el, end=' ')
            #     # print()
            elif arr[i]<end_el:
                arr[i+1]=end_el
                for el in arr:
                    print(el,end=' ')
                print()
                break
            if i==0:
                arr[i+1]=arr[i]
                arr[i]=end_el
                for el in arr:
                    print(el, end=' ')
                print()


# if __name__ == '__main__':
#     n = int(input())

#     arr = list(map(int, input().rstrip().split()))

#     insertionSort1(n, arr)
