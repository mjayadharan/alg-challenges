# %% [markdown]
# ![Screenshot%20from%202020-05-26%2023-34-41.png](attachment:Screenshot%20from%202020-05-26%2023-34-41.png)

# %% [markdown]
# Solution can be found on geeksforgeeks [here](https://www.geeksforgeeks.org/count-inversions-array-set-3-using-bit/)
